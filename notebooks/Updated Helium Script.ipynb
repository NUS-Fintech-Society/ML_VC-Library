# %%
from helium import *
import selenium as selenium
from selenium.webdriver import ChromeOptions
import pandas as pd
import time

# %%
icon_mapping = {
    "M12,2C8.1,2,5,5.1,5,9c0,5.2,7,13,7,13s7-7.8,7-13C19,5.1,15.9,2,12,2z M12,11.5c-1.4,0-2.5-1.1-2.5-2.5s1.1-2.5,2.5-2.5s2.5,1.1,2.5,2.5S13.4,11.5,12,11.5z": 'location',
    "M16.36,10.91a3.28,3.28,0,1,0-3.27-3.27A3.26,3.26,0,0,0,16.36,10.91Zm-8.72,0A3.28,3.28,0,1,0,4.36,7.64,3.26,3.26,0,0,0,7.64,10.91Zm0,2.18C5.09,13.09,0,14.37,0,16.91v2.73H15.27V16.91C15.27,14.37,10.18,13.09,7.64,13.09Zm8.72,0a10.24,10.24,0,0,0-1,.06,4.59,4.59,0,0,1,2.14,3.76v2.73H24V16.91C24,14.37,18.91,13.09,16.36,13.09Z": "employee",
    "M12,2C6.5,2,2,6.5,2,12s4.5,10,10,10s10-4.5,10-10S17.5,2,12,2z M11,19.9c-3.9-0.5-7-3.9-7-7.9c0-0.6,0.1-1.2,0.2-1.8L9,15v1c0,1.1,0.9,2,2,2V19.9z M17.9,17.4c-0.3-0.8-1-1.4-1.9-1.4h-1v-3c0-0.6-0.4-1-1-1H8v-2h2c0.6,0,1-0.4,1-1V7h2c1.1,0,2-0.9,2-2V4.6c2.9,1.2,5,4.1,5,7.4C20,14.1,19.2,16,17.9,17.4z": "website",
    "M21.3,0H2.7C1.2,0,0,1.2,0,2.7v18.7C0,22.8,1.2,24,2.7,24h18.7c1.5,0,2.7-1.2,2.7-2.7V2.7C24,1.2,22.8,0,21.3,0z M21.3,21.3H2.7V2.7h18.7V21.3z": "rank",
    "M9,10.71A3.87,3.87,0,1,0,5.15,6.85,3.85,3.85,0,0,0,9,10.71Zm0,2.58c-3,0-9,1.51-9,4.51V21H18V17.8C18,14.8,12,13.29,9,13.29Z": "investor",
    "M8.44679391,9.59786248 L8.44679391,10.7127564 C9.51041577,10.9723892 10.0449539,11.7763782 10.0798625,12.6523663 L8.95515061,12.6523663 C8.92569647,12.016375 8.58861016,11.58329 7.68316796,11.58329 C6.82245242,11.58329 6.30864125,11.9705574 6.30864125,12.5247317 C6.30864125,13.0090887 6.67954528,13.3189027 7.83589315,13.6199895 C8.99115012,13.9199854 10.2282242,14.4141604 10.2282242,15.8595953 C10.2282242,16.903581 9.43950764,17.4784823 8.44679391,17.6661161 L8.44679391,18.7613739 L6.91954201,18.7613739 L6.91954201,17.6573889 C5.94210079,17.4479373 5.10756671,16.821764 5.04647664,15.7068701 L6.16464321,15.7068701 C6.2224606,16.3068619 6.63481862,16.7759464 7.68316796,16.7759464 C8.806789,16.7759464 9.05769467,16.2152268 9.05769467,15.8650497 C9.05769467,15.3916017 8.80351632,14.9432441 7.53044277,14.6377938 C6.1090076,14.2974348 5.13702086,13.7116246 5.13702086,12.5345497 C5.13702086,11.5527449 5.93119185,10.9112991 6.91954201,10.6974839 L6.91954201,9.59786248 L8.44679391,9.59786248 Z M1.5272519,20.2886258 L13.7452671,20.2886258 L13.7452671,8.07061058 L1.5272519,8.07061058 L1.5272519,20.2886258 Z M13.7452671,6.54335868 C14.5863465,6.54335868 15.272519,7.23062204 15.272519,8.07061058 L15.272519,20.2886258 C15.272519,21.1286143 14.5863465,21.8158777 13.7452671,21.8158777 L1.5272519,21.8158777 C0.687263355,21.8158777 -5.68434189e-14,21.1286143 -5.68434189e-14,20.2886258 L-5.68434189e-14,8.07061058 C-5.68434189e-14,7.23062204 0.687263355,6.54335868 1.5272519,6.54335868 L13.7452671,6.54335868 Z M24,13.0889422 L24,15.2707306 L17.4546347,15.2707306 L17.4546347,13.0889422 L24,13.0889422 Z M24,7.63447108 L24,9.81625951 L17.4546347,9.81625951 L17.4546347,7.63447108 L24,7.63447108 Z M24,2.18 L24,4.36178843 L12.0001636,4.36178843 L12.0001636,2.18 L24,2.18 Z": "investment_stage",
    "M12.52,10.53c-3-.78-4-1.6-4-2.86,0-1.46,1.35-2.47,3.6-2.47S15.37,6.33,15.45,8H18.4a5.31,5.31,0,0,0-4.28-5.08V0h-4V2.88c-2.59.56-4.67,2.24-4.67,4.81,0,3.08,2.55,4.62,6.27,5.51,3.33.8,4,2,4,3.21,0,.92-.65,2.39-3.6,2.39-2.75,0-3.83-1.23-4-2.8H5.21c.16,2.92,2.35,4.56,4.91,5.11V24h4V21.13c2.6-.49,4.67-2,4.67-4.73C18.79,12.61,15.55,11.32,12.52,10.53Z": "last_funding",
    "M14.4,6L14,4H5v17h2v-7h5.6l0.4,2h7V6H14.4z": "ipo_status",
}

# %%
class CrunchBaseScrapper:
    driver = None

    def __init__(self, headless=False):
        options = selenium.webdriver.ChromeOptions()
        options.add_argument('--start-maximized')
        self.driver = start_chrome(headless=headless, options=options)

    def go_company_ranking(self, ranking):
        if not self.driver:
            raise Exception("Driver not initialised")
        go_to(
            f"https://www.crunchbase.com/search/organization.companies/field/organizations/rank_org_company/{ranking}")
#         wait_until(Text("Organization Name").exists)
        if Text("Press & Hold").exists():
            print("error")

        if Text("Organization Name").exists():
            click(Link(below="Organization Name"))
            time.sleep(3)

    def scrape_information(self):
        profile_name = cbs.driver.current_url.split('/')[-1:]
        profile_type = self._get_profile_type()
        general_info = self._get_general_information()
        about = self._get_about()
        highlights = self._get_highlights()
        details = self._get_details()
        
        # check if its investment firm
        if profile_type == "INVESTMENT FIRM":
            ## Summary Page
            # general info
            if about is not None:
                all_abouts.append(about[0])

            if profile_name is not None:
                all_names.append(profile_name[0])
            if 'location' in general_info:
                all_locations.append(general_info['location'])
            if 'employee' in general_info:
                all_no_employees.append(general_info['employee'])
            if 'investor' in general_info:
                all_investor_type.append(general_info['investor'])
            if 'investmentstage' in general_info:
                all_investment_stages.append(general_info['investmentstage'])
            if 'website' in general_info:
                all_websites.append(general_info['website'])
            
            # Highlights
            if 'Number of Funds' in highlights:
                all_no_funds.append(highlights['Number of Funds'])
            if 'Number of Acquisitions' in highlights:
                all_no_acquisitions.append(highlights['Number of Acquisitions'])
            if 'Number of Investments' in highlights:
                all_no_investments.append(highlights['Number of Investments'])
            if 'Number of Diversity Investments' in highlights:
                all_no_diversity_investments.append(highlights['Number of Diversity Investments'])
            if 'Number of Exits' in highlights:
                all_no_exits.append(highlights['Number of Exits'])
            if 'Total Funding Amount' in highlights:
                all_total_funding_amt.append(highlights['Total Funding Amount'])
    
            # Details
            if 'Industries' in details:
                all_industries.append(details['Industries'])
            if 'Founded Date' in details:
                all_founded_date.append(details['Founded Date'])
            if 'Founders' in details:
                all_founders.append(details['Founders'])
            if 'Operating Status' in details:
                all_operating_status.append(details['Operating Status'])
            if 'Last Funding Type' in details:
                all_last_funding_types.append(details['Last Funding Type'])
            if 'Headquarters Regions' in details:
                all_hqs.append(details['Headquarters Regions'])
            if 'Stock Symbol' in details:
                all_stock_symbols.append(details['Stock Symbol'])
            if 'Related Hub' in details:
                all_hub_tags.append(details['Related Hub'])
            if 'Company Type' in details:
                all_company_types.append(details['Company Type'])
            
            ##Financials Page
            go_to(
            f"https://www.crunchbase.com/organization/{profile_name[0].lower()}/investor_financials")
#             print("Went to Financials Page")
            # highlights
            highlights2 = self._get_highlights()
#             print(highlights2)
            if 'Number of Funding Rounds' in highlights2:
                all_no_funding_rounds.append(highlights2['Number of Funding Rounds'])
#                 print('number of funding rounds', highlights2['Number of Funding Rounds'])
            if 'Number of Lead Investors' in highlights2:
                all_no_lead_investors.append(highlights2['Number of Lead Investors'])
#                 print('number of lead investors', highlights2['Number of Lead Investors'])
            if 'Number of Investors' in highlights2:
                all_no_investors.append(highlights2['Number of Investors'])
#                 print('number of investors', highlights2['Number of Investors'])
            
            ##Investments Page
            go_to(
            f"https://www.crunchbase.com/organization/{profile_name[0].lower()}/recent_investments")
#             print("Went to Investments Page")
            highlights3 = self._get_highlights()
#             print(highlights3)
            if 'Number of Lead Investments' in highlights3:
                all_no_lead_investments.append(highlights3['Number of Lead Investments'])
            
            
            ##People Page
            go_to(
            f"https://www.crunchbase.com/organization/{profile_name[0].lower()}/people")
#             print("Went to Investments Page")
            highlights4 = self._get_highlights()
#             print(highlights4)
            if 'Number of Board Members / Advisors' in highlights4:
                all_no_board_members.append(highlights4['Number of Board Members / Advisors'])
            
            
            ##Technology Page
            go_to(
            f"https://www.crunchbase.com/organization/{profile_name[0].lower()}/technology")
#             print("Went to Technology Page")
            # highlights
            highlights5 = self._get_highlights()
#             print(highlights5)
            if 'Total Products Active' in highlights5:
                all_total_products_active.append(highlights5['Total Products Active'])
#                 print('total products active', highlights5['Number of Funding Rounds'])
            if 'Active Tech Count' in highlights5:
                all_active_tech_count.append(highlights5['Active Tech Count'])
#                 print('acitve tech count', highlights5['Active Tech Count'])
            if 'Monthly Visits' in highlights5:
                all_monthly_visits.append(highlights5['Monthly Visits'])
#                 print('number of investors', highlights5['Number of Investors'])
            if 'Monthly Visits Growth' in highlights5:
                all_monthly_visit_growth.append(highlights5['Monthly Visits Growth'])
#                 print('monthly visits growth', highlights5['Monthly Visits Growth'])
    
    
            ##Signals & News Page
            go_to(
            f"https://www.crunchbase.com/organization/{profile_name[0].lower()}/signals_and_news")
#             print("Went to signals&news Page")
            ## function to get number of articles 
            ## function to get number of events
            

        
        if profile_type == "ORGANIZATION":
            ## Summary Page
            # general info
            if about is not None:
                all_abouts.append(about[0])
                
            if profile_name is not None:
                all_names.append(profile_name[0])
            if 'location' in general_info:
                all_locations.append(general_info['location'])
            if 'employee' in general_info:
                all_no_employees.append(general_info['employee'])
#             if 'last_funding' in general_info:
#                 all_last_funding_types.append(general_info['last_funding'])
            if 'ipo_status' in general_info:
                all_ipo_status.append(general_info['ipo_status'])
            if 'website' in general_info:
                all_websites.append(general_info['website'])

            #Highlights  
            if 'Number of Acquisitions' in highlights:
                all_no_acquisitions.append(highlights['Number of Acquisitions'])
            if 'Number of Investments' in highlights:
                all_no_investments.append(highlights['Number of Investments'])
            if 'Total Funding Amount' in highlights:
                all_total_funding_amt.append(highlights['Total Funding Amount'])
            if 'Number of Current Team Members' in highlights:
                all_no_current_team.append(highlights['Number of Current Team Members'])
            if 'Number of Investors' in highlights:
                all_no_investors.append(highlights['Number of Investors'])

            # Details
            if 'Industries' in details:
                all_industries.append(details['Industries'])
            if 'Headquarters Regions' in details:
                all_hqs.append(details['Headquarters Regions'])
            if 'Founded Date' in details:
                all_founded_date.append(details['Founded Date'])
            if 'Founders' in details:
                all_founders.append(details['Founders'])
            if 'Operating Status' in details:
                all_operating_status.append(details['Operating Status'])
            if 'Last Funding Type' in details:
                all_last_funding_types.append(details['Last Funding Type'])
            if 'Related Hub' in details:
                all_hub_tags.append(details['Related Hub'])
            if 'Company Type' in details:
                all_company_types.append(details['Company Type'])
                
        
            ## Financials Page
            go_to(
            f"https://www.crunchbase.com/organization/{profile_name[0].lower()}/company_financials")
#             print("Went to Financials Page")
            highlights2 = self._get_highlights()
#             print(highlights2)
            if 'Number of Funding Rounds' in highlights2:
                all_no_funding_rounds.append(highlights2['Number of Funding Rounds'])
                #print('number of funding rounds', highlights2['Number of Funding Rounds'])
            if 'Number of Lead Investors' in highlights2:
                all_no_lead_investors.append(highlights2['Number of Lead Investors'])
#                 print('number of lead investors', highlights2['Number of Lead Investors'])
            if 'Number of Lead Investments' in highlights2:
                all_no_lead_investments.append(highlights2['Number of Lead Investments'])
                #print('number of lead investments', highlights2['Number of Lead Investments'])
            if 'Number of Exits' in highlights2:
                all_no_exits.append(highlights2['Number of Exits'])
                #print('number of exits', highlights2['Number of Exits'])
                
            ## People Page
            go_to(
            f"https://www.crunchbase.com/organization/{profile_name[0].lower()}/people")
#             print("Went to Investments Page")
            highlights4 = self._get_highlights()
#             print(highlights4)
            if 'Number of Board Members / Advisors' in highlights4:
                all_no_board_members.append(highlights4['Number of Board Members / Advisors'])
            
            
            ## Technology Page
            go_to(
            f"https://www.crunchbase.com/organization/{profile_name[0].lower()}/technology")
#             print("Went to Technology Page")
            # highlights
            highlights5 = self._get_highlights()
#             print(highlights5)
            if 'Total Products Active' in highlights5:
                all_total_products_active.append(highlights5['Total Products Active'])
                #print('total products active', highlights5['Number of Funding Rounds'])
            if 'Active Tech Count' in highlights5:
                all_active_tech_count.append(highlights5['Active Tech Count'])
                #print('acitve tech count', highlights5['Active Tech Count'])
            if 'Monthly Visits' in highlights5:
                all_monthly_visits.append(highlights5['Monthly Visits'])
                #print('number of investors', highlights5['Number of Investors'])
            if 'Monthly Visits Growth' in highlights5:
                all_monthly_visit_growth.append(highlights5['Monthly Visits Growth'])
                #print('monthly visits growth', highlights5['Monthly Visits Growth'])
            
            ##Signals & News Page
            go_to(
            f"https://www.crunchbase.com/organization/{profile_name[0].lower()}/signals_and_news")
#             print("Went to signals&news Page")
            ## function to get number of articles 
            ## function to get number of events
            
            
    def _check_driver(self):
        if not self.driver:
            raise Exception("Driver not initialised")

    def _get_profile_type(self):
        self._check_driver()
        profile_type = [cell.web_element.text for cell in find_all(S(".profile-type"))]
        return profile_type[0] if profile_type else ""

    def _get_profile_name(self):
        self._check_driver()
        profile_name = [cell.web_element.text for cell in find_all(S(".profile-name"))]
        return profile_name if profile_name else ""
    
    def _get_location(self):
        self._check_driver()
        location = [cell.web_element.text for cell in find_all(S("fields-card > ul > li > label-with-icon > span"))]
        return location

    def _get_general_information(self):
        self._check_driver()
        obj = {}
        element = S("fields-card > ul > li > label-with-icon")
        items = find_all(element)
        general_list = [(cell.web_element.find_element_by_tag_name('path').get_attribute("d"), cell.web_element.text)
                        for cell in items]
        for key, value in general_list:
            obj[icon_mapping[key]] = value
        return obj

    def _get_about(self):
        self._check_driver()
        if Button("READ MORE").exists():
            click(Button("READ MORE"))
        about = [cell.web_element.text for cell in find_all(S("description-card > div > span"))]
        short_about = about
        long_about = ", ".join(about[1:])
        return short_about, long_about

    def _get_highlights(self):
        self._check_driver()
        obj = {}
        highlight_element = S("profile-section > section-card > mat-card > div > div > anchored-values > div > a > div")
        highlight_list = [cell.web_element.text.split("\n") for cell in find_all(highlight_element)]
        res = list(map(lambda x: (", ".join(x[:-1]).strip(), x[-1]), highlight_list))
        for key, value in res:
            obj[key] = value
        return obj
    
#     def _get_highlights2(self):
#         self._check_driver()
#         obj = {}
#         highlight_element = S("profile-section > section-card > mat-card > div > div > anchored-values > div > a > div")
#         highlight_list = [cell.web_element.text.split("\n") for cell in find_all(highlight_element)]
#         res = list(map(lambda x: (", ".join(x[:-1]).strip(), x[-1]), highlight_list))
#         for key, value in res:
#             obj[key] = value
#         return obj

    def _get_details(self):
        self._check_driver()
        obj = {}
        detail_element = S("row-card > profile-section > section-card > mat-card > div > div > fields-card > ul > li")
        detail_list = [cell.web_element.text.split("\n") for cell in find_all(detail_element)]
        res = list(map(lambda x: (", ".join(x[:1]).strip(), x[1:]), detail_list))
        for key, value in res:
            obj[key] = value
        return obj

# %%
all_rnklst = []
all_names = []
all_websites = []
all_acquired_by = []
all_abouts = []
all_locations = []
all_no_employees = []
all_industries = []
all_ipo_status = []
all_founded_date = []
all_hqs = []
all_founders = []
all_operating_status = []
all_hub_tags = []
all_last_funding_types = []
all_company_types = []
all_investor_type = []
all_investment_stages = []
all_no_investors = []
all_no_funding_rounds = []
all_total_funding_amt = []
all_no_funds = []
all_no_investments = []
all_no_diversity_investments = []
all_no_exits = []
all_stock_symbols = []
all_no_lead_investors = []
all_no_lead_investments = []
all_no_acquisitions = []
all_no_current_team = []
all_no_board_members = []
all_total_products_active = []
all_product_downloads = []
all_active_tech_count = []
all_monthly_visits = []
all_monthly_visit_growth = []
all_no_articles = []
all_no_events = []
temp_list = []

big_array = [all_rnklst, all_names, all_acquired_by, all_abouts, all_locations,
             all_no_employees, all_industries, all_ipo_status, all_websites, all_founded_date,
             all_hqs, all_founders, all_operating_status, all_hub_tags,
             all_last_funding_types, all_company_types, all_investor_type, all_investment_stages,
             all_no_investors, all_no_funding_rounds, all_total_funding_amt,
             all_no_funds, all_no_investments, all_no_diversity_investments, all_no_exits,
             all_stock_symbols, all_no_lead_investors, all_no_lead_investments, all_no_acquisitions,
             all_no_current_team, all_no_board_members, all_total_products_active,
             all_product_downloads, all_active_tech_count, all_monthly_visits,
             all_monthly_visit_growth, all_no_articles, all_no_events, temp_list]

# %%
# Script Starts Here
for i in range(1, 3):
    cbs = CrunchBaseScrapper()
    cbs.go_company_ranking(i)
    all_rnklst.append(i)
    cbs.scrape_information()
    for j in big_array:
        if len(j) != i:
            j.append("NA")
    kill_browser()

# cbs.go_company_ranking(4)
# all_rnklst.append(4)
# cbs.scrape_information()
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-18-29c88c1d9924> in <module>
#       2 for i in range(1, 3):
#       3     cbs = CrunchBaseScrapper()
# ----> 4     cbs.go_company_ranking(i)
#       5     all_rnklst.append(i)
#       6     cbs.scrape_information()
#
# <ipython-input-9-43a7c2433dff> in go_company_ranking(self, ranking)
#      13             f"https://www.crunchbase.com/search/organization.companies/field/organizations/rank_org_company/{ranking}")
#      14 #         wait_until(Text("Organization Name").exists)
# ---> 15         if Text("Press & Hold").exists():
#      16             print("error")
#      17
#
# ~\anaconda3\lib\site-packages\helium\__init__.py in exists(self)
#     523                 Evaluates to true if this GUI element exists.
#     524 		"""
# --> 525                 return self._impl.exists()
#     526         def with_impl(self, impl):
#     527                 result = copy(self)
#
# ~\anaconda3\lib\site-packages\helium\_impl\__init__.py in exists(self)
#     615         def exists(self):
#     616                 try:
# --> 617                         next(self.find_all())
#     618                 except StopIteration:
#     619                         return False
#
# ~\anaconda3\lib\site-packages\helium\_impl\__init__.py in find_all(self)
#     603                         yield self
#     604                 else:
# --> 605                         for occurrence in self.find_all_occurrences():
#     606                                 yield self.bound_to_occurrence(occurrence)
#     607         def _is_bound(self):
#
# ~\anaconda3\lib\site-packages\helium\_impl\__init__.py in find_all_occurrences(self)
#     702                 return self.first_occurrence.unwrap()
#     703         def find_all_occurrences(self):
# --> 704                 self._handle_closed_window()
#     705                 self._driver.switch_to.default_content()
#     706                 try:
#
# ~\anaconda3\lib\site-packages\helium\_impl\__init__.py in _handle_closed_window(self)
#     715                         pass
#     716         def _handle_closed_window(self):
# --> 717                 window_handles = self._driver.window_handles
#     718                 try:
#     719                         curr_window_handle = self._driver.current_window_handle
#
# ~\anaconda3\lib\site-packages\helium\_impl\selenium_wrappers.py in __getattr__(self, item)
#      10                 self.target = target
#      11         def __getattr__(self, item):
# ---> 12                 return getattr(self.target, item)
#      13         def unwrap(self):
#      14                 return self.target
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in window_handles(self)
#     724             return self.execute(Command.W3C_GET_WINDOW_HANDLES)['value']
#     725         else:
# --> 726             return self.execute(Command.GET_WINDOW_HANDLES)['value']
#     727
#     728     def maximize_window(self):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: chrome not reachable
#   (Session info: chrome=88.0.4324.190)
#   (Driver info: chromedriver=2.38.552522 (437e6fbedfa8762dec75e2c5b3ddb86763dc9dcb),platform=Windows NT 10.0.18363 x86_64)

# %%
# cbs = CrunchBaseScrapper()
# cbs.go_company_ranking(1)

# # from selenium import webdriver 
  
# # import Action chains  
# from selenium.webdriver.common.action_chains import ActionChains 
 
# # get element
# element = cbs.driver.find_element_by_xpath('/html/body/div/div/div')
# wait_until(element.exists)
  
# # create action chain object 
# action = ActionChains(driver)
  
# # click and hold  the item 
# action.click_and_hold(on_element = element) 
  
# # perform the operation 
# action.perform()

# %%
for i in big_array:
    print(i)
# Out:
# [1, 1, 'NA', 2, 'NA', 3, 'NA', 4, 'NA', 5, 'NA', 6, 'NA', 1, 'NA', 2, 'NA', 3, 'NA', 4, 'NA', 5, 'NA', 6, 'NA', 7, 'NA', 8, 'NA', 9, 'NA', 10, 'NA', 11, 'NA', 12, 'NA', 13, 'NA', 14, 'NA', 15, 'NA', 16, 'NA', 17, 'NA', 18, 'NA', 19, 'NA']
# ['crowdcube', 'compassinc', 'NA', 'calendly', 'spotify', 'blocpower', 'crowdcube', 'NA', 'compassinc', 'NA', 'ant-group', 'NA', 'calendly', 'NA', 'spotify', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'rover-com', 'NA', 'citigroup', 'NA', 'zoom-video-communications', 'NA', 'unacademy', 'NA', 'goldman-sachs', 'NA', 'facebook', 'NA', 'drift', 'NA', 'crowdstrike', 'NA']
# ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']
# [['Crowdcube is an equity crowdfunding platform for entrepreneurs of start-ups and growing businesses.', 'Crowdcube is an equity crowdfunding platform for entrepreneurs of start-ups and growing businesses. Crowdcube enables individuals to invest or loan in small companies in return for equity or an annual return.\nAs an investment crowdfunding platform, Crowdcube enables entrepreneurs to raise finance with the added benefit of being backed by the', 'crowd. For investors, Crowdcube provides a way to handpick a stake in an innovative business that traditionally would have been restricted to corporate investors.\nSince Crowdcube first pioneered equity crowdfunding in 2011, a total of £300m has been invested through the platform from a crowd of over 390,000 investors, with more than £230m successfully invested in 520 raises. Businesses like the challenger bank Monzo, which raised £1 million in a record-breaking 96 seconds, as well as household brand names such as River Cottage and the Eden Project along with venture capital-backed businesses such as JustPark, eMoov and Sugru have all successfully raised growth funding from the crowd.'], ['Compass is a real estate technology company that provides an online platform for buying, renting, and selling real estate assets.', 'Washington D.C., South Florida, The Hamptons, Santa Barbara & Montecito, San Diego, Seattle & Eastside, Philadelphia, Connecticut, Westchester, Aspen, Boulder, Denver, Atlanta, Austin & Central Texas, Dallas-Fort Worth, Houston, Nashville, and Lake Tahoe.'], 'NA', ['Calendly is an automated scheduling tool that takes the work out of connecting with others so that its users can accomplish more.', 'Calendly is a scheduling software that delights customers and makes life easy for business professionals.\nCalendly users sell more, sell faster, and provide high-quality service by eliminating email and phone tag for scheduling meetings and appointments. Calendly is committed to creating an elegant and frustration-free scheduling experience', 'possible, so users can save time, impress their contacts and say goodbye to busywork.'], ['Spotify is a commercial music streaming service that provides restricted digital content from a range of record labels and artists.', 'Spotify is a commercial music streaming service that provides restricted digital content from a range of record labels and artists. Users can browse through the interface by artist, album, genre, playlist, record label, and direct searches.\nIt also enables individuals to create, share, and edit playlists with other users. If users want', 'recommendations, they can integrate their system with Last.fm, an application that provides music recommendations based on listening history. The radio feature installed in Spotify creates random playlists for its users that are related to preferred artists.\nSpotify is available for mobile device platforms such as Android, Blackberry, Boxee, iOS, Linux, MeeGo, Squeezebox, Windows mobile, and more.'], ['BlocPower is an energy technology startup that develops healthier, greener, and smarter cities.', 'BlocPower is an energy technology startup that develops healthier, greener, and smarter buildings.\nIt leverages advanced technologies, innovative electrification equipment, and structured finance to provide green heating and cooling to urban buildings. The company also connects government agencies, utilities, building owners, and smart equipment', 'providers to identify unhealthy, energy-wasting buildings to retrofit. Its propriety machine learning platform then determines which retrofits will produce the most energy savings at scale and uses the cloud and IoT to gather data and remotely monitor energy consumption. Since its founding, BlocPower has completed energy projects in nearly 1,000 buildings and delivers results ahead of schedule and under budget. It utilizes its proprietary software for analysis, leasing, project management, and monitoring of urban clean energy projects  ...
# ['Exeter, Devon, United Kingdom', 'New York, New York, United States', 'NA', 'Atlanta, Georgia, United States', 'Stockholm, Stockholms Lan, Sweden', 'Brooklyn, New York, United States', 'Exeter, Devon, United Kingdom', 'NA', 'New York, New York, United States', 'NA', 'Hangzhou, Zhejiang, China', 'NA', 'Atlanta, Georgia, United States', 'NA', 'Stockholm, Stockholms Lan, Sweden', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'Seattle, Washington, United States', 'NA', 'New York, New York, United States', 'NA', 'San Jose, California, United States', 'NA', 'Bangalore, Karnataka, India', 'NA', 'New York, New York, United States', 'NA', 'Menlo Park, California, United States', 'NA', 'Boston, Massachusetts, United States', 'NA', 'Sunnyvale, California, United States', 'NA']
# ['51-100', '10001+', 'NA', '101-250', '1001-5000', '51-100', '51-100', 'NA', '10001+', 'NA', '5001-10000', 'NA', '101-250', 'NA', '1001-5000', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '251-500', 'NA', '10001+', 'NA', '1001-5000', 'NA', '251-500', 'NA', '10001+', 'NA', '10001+', 'NA', '251-500', 'NA', '501-1000', 'NA']
# [['Business Development', 'Finance', 'Financial Services', 'FinTech', 'Funding Platform', 'Venture Capital'], ['E-Commerce Platforms', 'Property Management', 'Real Estate'], 'NA', ['Productivity Tools', 'Recruiting', 'Scheduling', 'Software'], ['Cloud Computing', 'Music', 'Music Streaming', 'Video Streaming'], ['Clean Energy', 'CleanTech', 'Energy Efficiency', 'Energy Management', 'Smart Cities'], ['Business Development', 'Finance', 'Financial Services', 'FinTech', 'Funding Platform', 'Venture Capital'], 'NA', ['E-Commerce Platforms', 'Property Management', 'Real Estate'], 'NA', ['Banking', 'E-Commerce', 'Financial Services', 'FinTech', 'Internet', 'Payments', 'Wealth Management'], 'NA', ['Productivity Tools', 'Recruiting', 'Scheduling', 'Software'], 'NA', ['Cloud Computing', 'Music', 'Music Streaming', 'Video Streaming'], 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', ['Consumer', 'Marketplace', 'Pet'], 'NA', ['Banking', 'Credit Cards', 'Financial Services', 'Wealth Management'], 'NA', ['Collaboration', 'Information Technology', 'Messaging', 'Video Conferencing'], 'NA', ['E-Learning', 'EdTech', 'Education', 'Training'], 'NA', ['Banking', 'Finance', 'Financial Services', 'Security', 'Venture Capital'], 'NA', ['Mobile Apps', 'Social', 'Social Media', 'Social Network'], 'NA', ['Apps', 'Enterprise Software', 'Internet', 'Marketing Automation', 'Sales Automation', 'Software'], 'NA', ['Crowdsourcing', 'Cyber Security', 'Network Security', 'SaaS', 'Security'], 'NA']
# ['NA', 'Private', 'NA', 'Private', 'Public', 'Private', 'NA', 'Private', 'NA', 'Private', 'NA', 'Private', 'NA', 'Public', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'Private', 'NA', 'NA', 'Public', 'NA', 'Private', 'NA', 'NA', 'Public', 'NA', 'Private', 'NA', 'Public', 'NA']
# ['www.crowdcube.com/', 'www.compass.com', 'NA', 'calendly.com', 'www.spotify.com', 'www.blocpower.io', 'www.crowdcube.com/', 'NA', 'www.compass.com', 'NA', 'www.antgroup.com/', 'NA', 'calendly.com', 'NA', 'www.spotify.com', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'www.rover.com', 'NA', 'www.citigroup.com', 'NA', 'zoom.us', 'NA', 'unacademy.com/', 'NA', 'www.goldmansachs.com/', 'NA', 'www.facebook.com', 'NA', 'www.drift.com', 'NA', 'www.crowdstrike.com', 'NA']
# [['Aug 1, 2010'], ['Oct 4, 2012'], 'NA', ['2013'], ['Jul 14, 2006'], ['2014'], ['Aug 1, 2010'], 'NA', ['Oct 4, 2012'], 'NA', ['Oct 2014'], 'NA', ['2013'], 'NA', ['Jul 14, 2006'], 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', ['2011'], 'NA', ['Oct 8, 1998'], 'NA', ['2011'], 'NA', ['2015'], 'NA', ['Jan 1, 1869'], 'NA', ['Feb 4, 2004'], 'NA', ['2015'], 'NA', ['2011'], 'NA']
# ['NA', ['Greater New York Area, East Coast, Northeastern US'], 'NA', ['Greater Atlanta Area, East Coast, Southern US'], ['European Union (EU), Nordic Countries, Scandinavia'], ['Greater New York Area, East Coast, Northeastern US'], 'NA', ['Greater New York Area, East Coast, Northeastern US'], 'NA', ['Asia-Pacific (APAC)'], 'NA', ['Greater Atlanta Area, East Coast, Southern US'], 'NA', ['European Union (EU), Nordic Countries, Scandinavia'], 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', ['Greater Seattle Area, West Coast, Western US'], 'NA', ['Greater New York Area, East Coast, Northeastern US'], 'NA', ['San Francisco Bay Area, Silicon Valley, West Coast'], 'NA', ['Asia-Pacific (APAC)'], 'NA', ['Greater New York Area, East Coast, Northeastern US'], 'NA', ['San Francisco Bay Area, Silicon Valley, West Coast'], 'NA', ['Greater Boston Area, East Coast, New England'], 'NA', ['San Francisco Bay Area, Silicon Valley, West Coast'], 'NA']
# [['Darren Westlake, Luke Lang, Mac Parish, Oriol Cordón, Pepe Borrell'], ['Ori Allon, Robert Reffkin, Ugo Di Girolamo'], 'NA', ['Tope Awotona'], ['Daniel Ek, Dilshan Randeer Ilangasinghe, Martin Lorentzon'], ['Donnel Baird, Morris Cox'], ['Darren Westlake, Luke Lang, Mac Parish, Oriol Cordón, Pepe Borrell'], 'NA', ['Ori Allon, Robert Reffkin, Ugo Di Girolamo'], 'NA', ['Lucy Peng'], 'NA', ['Tope Awotona'], 'NA', ['Daniel Ek, Dilshan Randeer Ilangasinghe, Martin Lorentzon'], 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', ['Aaron Easterly, Greg Gottesman, Philip Kimmey'], 'NA', 'NA', ['Eric Yuan'], 'NA', ['Gaurav Munjal, Hemesh Singh, Roman Saini, Sachin Gupta'], 'NA', 'NA', ['Andrew McCollum, Chris Hughes, Dustin Moskovitz, Eduardo Saverin, Mark Zuckerberg, Nicholas Daniel-Richards, Rob Jagnow'], 'NA', ['David Cancel, Elias Torres'], 'NA', ['Dmitri Alperovitch, George Kurtz, Gregg Marston'], 'NA']
# [['Active'], ['Active'], 'NA', ['Active'], ['Active'], ['Active'], ['Active'], 'NA', ['Active'], 'NA', ['Active'], 'NA', ['Active'], 'NA', ['Active'], 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', ['Active'], 'NA', ['Active'], 'NA', ['Active'], 'NA', ['Active'], 'NA', ['Active'], 'NA', ['Active'], 'NA', ['Active'], 'NA', ['Active'], 'NA']
# ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']
# [['Venture - Series Unknown'], ['Series G'], 'NA', ['Series B'], ['Corporate Round'], ['Debt Financing'], ['Venture - Series Unknown'], 'NA', ['Series G'], 'NA', ['Series C'], 'NA', ['Series B'], 'NA', ['Corporate Round'], 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', ['Series G'], 'NA', ['Post-IPO Equity'], 'NA', ['Post-IPO Equity'], 'NA', ['Venture - Series Unknown'], 'NA', 'NA', ['Post-IPO Equity'], 'NA', ['Series C'], 'NA', ['Series E'], 'NA']
# [['For Profit'], ['For Profit'], 'NA', ['For Profit'], ['For Profit'], ['For Profit'], ['For Profit'], 'NA', ['For Profit'], 'NA', ['For Profit'], 'NA', ['For Profit'], 'NA', ['For Profit'], 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', ['For Profit'], 'NA', ['For Profit'], 'NA', ['For Profit'], 'NA', ['For Profit'], 'NA', ['For Profit'], 'NA', ['For Profit'], 'NA', ['For Profit'], 'NA', ['For Profit'], 'NA']
# ['Venture Capital', 'NA', 'NA', 'NA', 'NA', 'NA', 'Venture Capital', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'Investment Bank', 'NA', 'NA', 'NA', 'Investment Bank, Venture Capital', 'NA', 'NA', 'NA', 'NA']
# ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']
# ['NA', '32', 'NA', '3', 'NA', '20', 'NA', '32', 'NA', '15', 'NA', '3', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '18', 'NA', 'NA', '18', 'NA', '36', 'NA', 'NA', '26', 'NA', '12', 'NA', '11', 'NA']
# ['NA', 'NA', 'NA', '2', '21', 'NA', 'NA', 'NA', '4', 'NA', 'NA', '21', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '7', 'NA', 'NA', 'NA', '17', 'NA', 'NA', '7', 'NA']
# ['£30.7M', '$1.5B', 'NA', '$350.6M', '$2.6B', '$75.9M', '£30.7M', 'NA', '$1.5B', 'NA', '$22B', 'NA', '$350.6M', 'NA', '$2.6B', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '$310.9M', 'NA', 'NA', '$146M', 'NA', '$398.5M', 'NA', 'NA', '$16.1B', 'NA', '$107M', 'NA', '$481M', 'NA']
# ['1', 'NA', 'NA', 'NA', 'NA', 'NA', '1', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '2', 'NA', 'NA', 'NA', '7', 'NA', 'NA', 'NA', 'NA']
# ['1,208', 'NA', 'NA', 'NA', '5', 'NA', '1,208', 'NA', 'NA', '96', 'NA', 'NA', '5', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '1', 'NA', '91', 'NA', '1', 'NA', 'NA', '808', 'NA', '35', 'NA', 'NA', '3', 'NA']
# ['16', 'NA', 'NA', 'NA', 'NA', 'NA', '16', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '5', 'NA', 'NA', 'NA', '38', 'NA', 'NA', 'NA', 'NA']
# ['28', 'NA', 'NA', 'NA', '1', 'NA', '28', 'NA', 'NA', '12', 'NA', 'NA', '1', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '21', 'NA', 'NA', 'NA', '261', 'NA', 'NA', 'NA', 'NA']
# ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', ['NYSE:C'], 'NA', 'NA', 'NA', ['NYSE:GS'], 'NA', 'NA', 'NA', 'NA']
# ['NA', 'NA', 'NA', '2', 'NA', 'NA', 'NA', 'NA', '4', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '4', 'NA', 'NA', 'NA', '11', 'NA', 'NA', '4', 'NA']
# ['NA', 'NA', 'NA', 'NA', '3', 'NA', '23', 'NA', 'NA', '54', 'NA', 'NA', '3', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '1', 'NA', 'NA', 'NA', '16', 'NA', 'NA', 'NA']
# ['1', '12', 'NA', 'NA', '19', 'NA', '1', 'NA', '12', 'NA', '5', 'NA', 'NA', '19', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '3', 'NA', '6', 'NA', '1', 'NA', '8', 'NA', '24', 'NA', '89', 'NA', '3', 'NA', '3', 'NA']
# ['NA', '35', 'NA', '6', '127', '5', 'NA', '35', 'NA', '41', 'NA', '6', 'NA', '127', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '8', 'NA', 'NA', '29', 'NA', '4', 'NA', 'NA', '852', 'NA', '13', 'NA', '44', 'NA']
# ['NA', 'NA', 'NA', 'NA', '10', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '21', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']
# ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '70', 'NA', '32', 'NA', 'NA', 'NA', 'NA', 'NA']
# ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']
# ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '97', 'NA', '67', 'NA', 'NA', 'NA', 'NA', 'NA']
# ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '1,147,671,725', 'NA', '6,964,648', 'NA', 'NA', 'NA', 'NA', 'NA']
# ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '8.52%', 'NA', '9.58%', 'NA', 'NA', 'NA', 'NA', 'NA']
# ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']
# ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']
# ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']

# %%
# combine list into dataframe and print

df = pd.DataFrame({
    'CrunchBase Ranking': all_rnklst,
    'Company Name/Organisation Name': all_names,
    'Acquired by': all_acquired_by,
    'About': all_abouts,
    'Location': all_locations,
    'Number of Employees': all_no_employees,
    'Industry': all_industries,
    'IPO Status': all_ipo_status,
    'Website': all_websites,
    'Founded Date': all_founded_date,
    'Headquarters': all_hqs,
    'Founders': all_founders,
    'Operating Status': all_operating_status,
    'Hub Tags': all_hub_tags,
    'Last Funding Type': all_last_funding_types,
    'Company Type': all_company_types,
    'Investor Type': all_investor_type,
    'Investment Stage': temp_list,
    'Number of Investors': all_no_investors,
    'Number Funding Rounds': all_no_funding_rounds,
    'Total Funding Amount': all_total_funding_amt,
    'Number of exits': all_no_exits,
    'Number of Lead Investors': all_no_lead_investors,
    'Number of Acquisitions': all_no_acquisitions,
    'Number of Current Team Members (core team)': all_no_current_team,
    'Number of Board Members/Advisors': all_no_board_members,
    'Total Products Active': all_total_products_active,
    'Product Downloads in the Last 30 Days': all_product_downloads,
    'Active Tech Count': all_active_tech_count,
    'Monthly Visits': all_monthly_visits,
    'Monthly Visits Growth': all_monthly_visit_growth,
    'Number of Articles': all_no_articles,
    'Number of Events': all_no_events,
    'Number of Funds': all_no_funds,
    'Number of Investments': all_no_investments,
    'Number of Diversity Investments': all_no_diversity_investments,
    'Number of Exits': all_no_exits,
    'Related Hubs': all_hub_tags,
    'Investor Type': temp_list,
    'Stock Symbol': all_stock_symbols,
    'IPO Date': temp_list,
    'Number of Sub': temp_list,
    'Organisations': temp_list,
    'Funding Rounds': temp_list,
    'Funds Raised (for VC)': temp_list,
    'Number of Lead Investments': temp_list
})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-be2e4608b51e> in <module>
#       1 # combine list into dataframe and print
#       2
# ----> 3 df = pd.DataFrame({
#       4     'CrunchBase Ranking': all_rnklst,
#       5     'Company Name/Organisation Name': all_names,
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     433             )
#     434         elif isinstance(data, dict):
# --> 435             mgr = init_dict(data, index, columns, dtype=dtype)
#     436         elif isinstance(data, ma.MaskedArray):
#     437             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     252             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     253         ]
# --> 254     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     255
#     256
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      62     # figure out the index, if necessary
#      63     if index is None:
# ---> 64         index = extract_index(arrays)
#      65     else:
#      66         index = ensure_index(index)
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in extract_index(data)
#     363             lengths = list(set(raw_lengths))
#     364             if len(lengths) > 1:
# --> 365                 raise ValueError("arrays must all be same length")
#     366
#     367             if have_dicts:
#
# ValueError: arrays must all be same length

# %%
df
