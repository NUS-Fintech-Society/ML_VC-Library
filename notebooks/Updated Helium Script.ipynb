# %%
from helium import *
import selenium as selenium
from selenium.webdriver import ChromeOptions
import pandas as pd
import time

# %%
icon_mapping = {
    "M12,2C8.1,2,5,5.1,5,9c0,5.2,7,13,7,13s7-7.8,7-13C19,5.1,15.9,2,12,2z M12,11.5c-1.4,0-2.5-1.1-2.5-2.5s1.1-2.5,2.5-2.5s2.5,1.1,2.5,2.5S13.4,11.5,12,11.5z": 'location',
    "M16.36,10.91a3.28,3.28,0,1,0-3.27-3.27A3.26,3.26,0,0,0,16.36,10.91Zm-8.72,0A3.28,3.28,0,1,0,4.36,7.64,3.26,3.26,0,0,0,7.64,10.91Zm0,2.18C5.09,13.09,0,14.37,0,16.91v2.73H15.27V16.91C15.27,14.37,10.18,13.09,7.64,13.09Zm8.72,0a10.24,10.24,0,0,0-1,.06,4.59,4.59,0,0,1,2.14,3.76v2.73H24V16.91C24,14.37,18.91,13.09,16.36,13.09Z": "employee",
    "M12,2C6.5,2,2,6.5,2,12s4.5,10,10,10s10-4.5,10-10S17.5,2,12,2z M11,19.9c-3.9-0.5-7-3.9-7-7.9c0-0.6,0.1-1.2,0.2-1.8L9,15v1c0,1.1,0.9,2,2,2V19.9z M17.9,17.4c-0.3-0.8-1-1.4-1.9-1.4h-1v-3c0-0.6-0.4-1-1-1H8v-2h2c0.6,0,1-0.4,1-1V7h2c1.1,0,2-0.9,2-2V4.6c2.9,1.2,5,4.1,5,7.4C20,14.1,19.2,16,17.9,17.4z": "website",
    "M21.3,0H2.7C1.2,0,0,1.2,0,2.7v18.7C0,22.8,1.2,24,2.7,24h18.7c1.5,0,2.7-1.2,2.7-2.7V2.7C24,1.2,22.8,0,21.3,0z M21.3,21.3H2.7V2.7h18.7V21.3z": "rank",
    "M9,10.71A3.87,3.87,0,1,0,5.15,6.85,3.85,3.85,0,0,0,9,10.71Zm0,2.58c-3,0-9,1.51-9,4.51V21H18V17.8C18,14.8,12,13.29,9,13.29Z": "investor",
    "M8.44679391,9.59786248 L8.44679391,10.7127564 C9.51041577,10.9723892 10.0449539,11.7763782 10.0798625,12.6523663 L8.95515061,12.6523663 C8.92569647,12.016375 8.58861016,11.58329 7.68316796,11.58329 C6.82245242,11.58329 6.30864125,11.9705574 6.30864125,12.5247317 C6.30864125,13.0090887 6.67954528,13.3189027 7.83589315,13.6199895 C8.99115012,13.9199854 10.2282242,14.4141604 10.2282242,15.8595953 C10.2282242,16.903581 9.43950764,17.4784823 8.44679391,17.6661161 L8.44679391,18.7613739 L6.91954201,18.7613739 L6.91954201,17.6573889 C5.94210079,17.4479373 5.10756671,16.821764 5.04647664,15.7068701 L6.16464321,15.7068701 C6.2224606,16.3068619 6.63481862,16.7759464 7.68316796,16.7759464 C8.806789,16.7759464 9.05769467,16.2152268 9.05769467,15.8650497 C9.05769467,15.3916017 8.80351632,14.9432441 7.53044277,14.6377938 C6.1090076,14.2974348 5.13702086,13.7116246 5.13702086,12.5345497 C5.13702086,11.5527449 5.93119185,10.9112991 6.91954201,10.6974839 L6.91954201,9.59786248 L8.44679391,9.59786248 Z M1.5272519,20.2886258 L13.7452671,20.2886258 L13.7452671,8.07061058 L1.5272519,8.07061058 L1.5272519,20.2886258 Z M13.7452671,6.54335868 C14.5863465,6.54335868 15.272519,7.23062204 15.272519,8.07061058 L15.272519,20.2886258 C15.272519,21.1286143 14.5863465,21.8158777 13.7452671,21.8158777 L1.5272519,21.8158777 C0.687263355,21.8158777 -5.68434189e-14,21.1286143 -5.68434189e-14,20.2886258 L-5.68434189e-14,8.07061058 C-5.68434189e-14,7.23062204 0.687263355,6.54335868 1.5272519,6.54335868 L13.7452671,6.54335868 Z M24,13.0889422 L24,15.2707306 L17.4546347,15.2707306 L17.4546347,13.0889422 L24,13.0889422 Z M24,7.63447108 L24,9.81625951 L17.4546347,9.81625951 L17.4546347,7.63447108 L24,7.63447108 Z M24,2.18 L24,4.36178843 L12.0001636,4.36178843 L12.0001636,2.18 L24,2.18 Z": "investment_stage",
    "M12.52,10.53c-3-.78-4-1.6-4-2.86,0-1.46,1.35-2.47,3.6-2.47S15.37,6.33,15.45,8H18.4a5.31,5.31,0,0,0-4.28-5.08V0h-4V2.88c-2.59.56-4.67,2.24-4.67,4.81,0,3.08,2.55,4.62,6.27,5.51,3.33.8,4,2,4,3.21,0,.92-.65,2.39-3.6,2.39-2.75,0-3.83-1.23-4-2.8H5.21c.16,2.92,2.35,4.56,4.91,5.11V24h4V21.13c2.6-.49,4.67-2,4.67-4.73C18.79,12.61,15.55,11.32,12.52,10.53Z": "last_funding",
    "M14.4,6L14,4H5v17h2v-7h5.6l0.4,2h7V6H14.4z": "ipo_status",
    "M20,7h-4V5c0-1.1-0.9-2-2-2h-4C8.9,3,8,3.9,8,5v2H4C2.9,7,2,7.9,2,9l0,11c0,1.1,0.9,2,2,2h16c1.1,0,2-0.9,2-2V9C22,7.9,21.1,7,20,7z M14,7h-4V5h4V7z":"hiring_status"
}

# %%
class CrunchBaseScrapper:
    driver = None

    def __init__(self, headless=False):
        options = selenium.webdriver.ChromeOptions()
        options.add_argument('--start-maximized')
        self.driver = start_chrome(headless=headless, options=options)

    def go_company_ranking(self, ranking):
        if not self.driver:
            raise Exception("Driver not initialised")
        go_to(
            f"https://www.crunchbase.com/search/organization.companies/field/organizations/rank_org_company/{ranking}")
        wait_until(Text("Organization Name").exists)
        if Text("Press & Hold").exists():
            print("the blocker came on cb")    
        if Text("Organization Name").exists():
            click(Link(below="Organization Name"))
            time.sleep(3)

    def scrape_information(self):
        profile_name = cbs.driver.current_url.split('/')[-1:]
        profile_type = self._get_profile_type()
        general_info = self._get_general_information()
        about = self._get_about()
        highlights = self._get_highlights()
        details = self._get_details()
        news = self._get_recentNews()
        
        # check if its investment firm
        if profile_type == "INVESTMENT FIRM":
            ## Summary Page
            # general info
            if about is not None:
                all_abouts.append(about[0])

            if profile_name is not None:
                all_names.append(profile_name[0])
            if 'location' in general_info:
                all_locations.append(general_info['location'])
            if 'employee' in general_info:
                all_no_employees.append(general_info['employee'])
            if 'investor' in general_info:
                all_investor_type.append(general_info['investor'])
            if 'investmentstage' in general_info:
                all_investment_stages.append(general_info['investmentstage'])
            if 'website' in general_info:
                all_websites.append(general_info['website'])
            
            # Highlights
            if 'Number of Funds' in highlights:
                all_no_funds.append(highlights['Number of Funds'])
            if 'Number of Acquisitions' in highlights:
                all_no_acquisitions.append(highlights['Number of Acquisitions'])
            if 'Number of Investments' in highlights:
                all_no_investments.append(highlights['Number of Investments'])
            if 'Number of Diversity Investments' in highlights:
                all_no_diversity_investments.append(highlights['Number of Diversity Investments'])
            if 'Number of Exits' in highlights:
                all_no_exits.append(highlights['Number of Exits'])
            if 'Total Funding Amount' in highlights:
                all_total_funding_amt.append(highlights['Total Funding Amount'])
    
            # Details
            if 'Industries' in details:
                all_industries.append(details['Industries'])
            if 'Founded Date' in details:
                all_founded_date.append(details['Founded Date'])
            if 'Founders' in details:
                all_founders.append(details['Founders'])
            if 'Operating Status' in details:
                all_operating_status.append(details['Operating Status'])
            if 'Last Funding Type' in details:
                all_last_funding_types.append(details['Last Funding Type'])
            if 'Headquarters Regions' in details:
                all_hqs.append(details['Headquarters Regions'])
            if 'Stock Symbol' in details:
                all_stock_symbols.append(details['Stock Symbol'])
            if 'Related Hub' in details:
                all_hub_tags.append(details['Related Hub'])
            if 'Company Type' in details:
                all_company_types.append(details['Company Type'])
            
            ##Financials Page
            go_to(
            f"https://www.crunchbase.com/organization/{profile_name[0].lower()}/investor_financials")
#             print("Went to Financials Page")
            # highlights
            highlights2 = self._get_highlights()
            if 'Number of Funding Rounds' in highlights2:
                all_no_funding_rounds.append(highlights2['Number of Funding Rounds'])
#                 print('number of funding rounds', highlights2['Number of Funding Rounds'])
            if 'Number of Lead Investors' in highlights2:
                all_no_lead_investors.append(highlights2['Number of Lead Investors'])
#                 print('number of lead investors', highlights2['Number of Lead Investors'])
            if 'Number of Investors' in highlights2:
                all_no_investors.append(highlights2['Number of Investors'])
#                 print('number of investors', highlights2['Number of Investors'])
            
            ##Investments Page
            go_to(
            f"https://www.crunchbase.com/organization/{profile_name[0].lower()}/recent_investments")
#             print("Went to Investments Page")
            highlights3 = self._get_highlights()
#             print(highlights3)
            if 'Number of Lead Investments' in highlights3:
                all_no_lead_investments.append(highlights3['Number of Lead Investments'])
            
            
            ##People Page
            go_to(
            f"https://www.crunchbase.com/organization/{profile_name[0].lower()}/people")
#             print("Went to Investments Page")
            highlights4 = self._get_highlights()
#             print(highlights4)
            if 'Number of Board Members / Advisors' in highlights4:
                all_no_board_members.append(highlights4['Number of Board Members / Advisors'])
                        
            if 'Number of Current Team' in highlights4:
                all_no_board_members.append(highlights4['Number of Current Team'])
            
            
            ##Technology Page
            go_to(
            f"https://www.crunchbase.com/organization/{profile_name[0].lower()}/technology")
#             print("Went to Technology Page")
            # highlights
            highlights5 = self._get_highlights()
#             print(highlights5)
            if 'Total Products Active' in highlights5:
                all_total_products_active.append(highlights5['Total Products Active'])
#                 print('total products active', highlights5['Number of Funding Rounds'])
            if 'Active Tech Count' in highlights5:
                all_active_tech_count.append(highlights5['Active Tech Count'])
#                 print('acitve tech count', highlights5['Active Tech Count'])
            if 'Monthly Visits' in highlights5:
                all_monthly_visits.append(highlights5['Monthly Visits'])
#                 print('number of investors', highlights5['Number of Investors'])
            if 'Monthly Visits Growth' in highlights5:
                all_monthly_visit_growth.append(highlights5['Monthly Visits Growth'])
#                 print('monthly visits growth', highlights5['Monthly Visits Growth'])
            if 'Downloads Last 30 Days' in highlights5:
                all_product_downloads.append(highlights5['Downloads Last 30 Days'])
    
            ##Signals & News Page
            go_to(
            f"https://www.crunchbase.com/organization/{profile_name[0].lower()}/signals_and_news")
            news = self._get_recentNews()
            if 'Number of Articles' in news:
                all_no_articles.append(news['Number of Articles'])
                #print(news['Number of Articles'])
            if 'Number of Events' in news:
                all_no_events.append(news['Number of Events'])
                #print(news['Number of Events'])
            

        
        if profile_type == "ORGANIZATION":
            ## Summary Page
            # general info
            if about is not None:
                all_abouts.append(about[0])
                
            if profile_name is not None:
                all_names.append(profile_name[0])
            if 'location' in general_info:
                all_locations.append(general_info['location'])
            if 'employee' in general_info:
                all_no_employees.append(general_info['employee'])
#             if 'last_funding' in general_info:
#                 all_last_funding_types.append(general_info['last_funding'])
            if 'ipo_status' in general_info:
                all_ipo_status.append(general_info['ipo_status'])
            if 'website' in general_info:
                all_websites.append(general_info['website'])

            #Highlights  
            if 'Number of Acquisitions' in highlights:
                all_no_acquisitions.append(highlights['Number of Acquisitions'])
            if 'Number of Investments' in highlights:
                all_no_investments.append(highlights['Number of Investments'])
            if 'Total Funding Amount' in highlights:
                all_total_funding_amt.append(highlights['Total Funding Amount'])
            if 'Number of Current Team Members' in highlights:
                all_no_current_team.append(highlights['Number of Current Team Members'])
            if 'Number of Investors' in highlights:
                all_no_investors.append(highlights['Number of Investors'])

            # Details
            if 'Industries' in details:
                all_industries.append(details['Industries'])
            if 'Headquarters Regions' in details:
                all_hqs.append(details['Headquarters Regions'])
            if 'Founded Date' in details:
                all_founded_date.append(details['Founded Date'])
            if 'Founders' in details:
                all_founders.append(details['Founders'])
            if 'Operating Status' in details:
                all_operating_status.append(details['Operating Status'])
            if 'Last Funding Type' in details:
                all_last_funding_types.append(details['Last Funding Type'])
            if 'Related Hub' in details:
                all_hub_tags.append(details['Related Hub'])
            if 'Company Type' in details:
                all_company_types.append(details['Company Type'])
                
        
            ## Financials Page
            go_to(
            f"https://www.crunchbase.com/organization/{profile_name[0].lower()}/company_financials")
#             print("Went to Financials Page")
            highlights2 = self._get_highlights()
#             print(highlights2)
            if 'Number of Funding Rounds' in highlights2:
                all_no_funding_rounds.append(highlights2['Number of Funding Rounds'])
                #print('number of funding rounds', highlights2['Number of Funding Rounds'])
            if 'Number of Lead Investors' in highlights2:
                all_no_lead_investors.append(highlights2['Number of Lead Investors'])
#                 print('number of lead investors', highlights2['Number of Lead Investors'])
            if 'Number of Lead Investments' in highlights2:
                all_no_lead_investments.append(highlights2['Number of Lead Investments'])
                #print('number of lead investments', highlights2['Number of Lead Investments'])
            if 'Number of Exits' in highlights2:
                all_no_exits.append(highlights2['Number of Exits'])
                #print('number of exits', highlights2['Number of Exits'])
                
            ## People Page
            go_to(
            f"https://www.crunchbase.com/organization/{profile_name[0].lower()}/people")
#             print("Went to Investments Page")
            highlights4 = self._get_highlights()
#             print(highlights4)
            if 'Number of Board Members /' in highlights4:
                all_no_board_members.append(highlights4['Number of Board Members /'])
            
            if 'Number of Current Team' in highlights4:
                all_no_board_members.append(highlights4['Number of Current Team'])
            
            
            ## Technology Page
            go_to(
            f"https://www.crunchbase.com/organization/{profile_name[0].lower()}/technology")
#             print("Went to Technology Page")
            # highlights
            highlights5 = self._get_highlights()
#             print(highlights5)
            if 'Total Products Active' in highlights5:
                all_total_products_active.append(highlights5['Total Products Active'])
                #print('total products active', highlights5['Number of Funding Rounds'])
            if 'Active Tech Count' in highlights5:
                all_active_tech_count.append(highlights5['Active Tech Count'])
                #print('acitve tech count', highlights5['Active Tech Count'])
            if 'Monthly Visits' in highlights5:
                all_monthly_visits.append(highlights5['Monthly Visits'])
                #print('number of investors', highlights5['Number of Investors'])
            if 'Monthly Visits Growth' in highlights5:
                all_monthly_visit_growth.append(highlights5['Monthly Visits Growth'])
                #print('monthly visits growth', highlights5['Monthly Visits Growth'])
            if 'Downloads Last 30 Days' in highlights5:
                all_product_downloads.append(highlights5['Downloads Last 30 Days'])
            
            ##Signals & News Page
            go_to(
            f"https://www.crunchbase.com/organization/{profile_name[0].lower()}/signals_and_news")
#             print("Went to signals&news Page")
            news = self._get_recentNews()
            if 'Number of Articles' in news:
                all_no_articles.append(news['Number of Articles'])
                #print(news['Number of Articles'])
            if 'Number of Events' in news:
                all_no_events.append(news['Number of Events'])
                #print(news['Number of Events'])

            
            
    def _check_driver(self):
        if not self.driver:
            raise Exception("Driver not initialised")

    def _get_profile_type(self):
        self._check_driver()
        profile_type = [cell.web_element.text for cell in find_all(S(".profile-type"))]
        return profile_type[0] if profile_type else ""

    def _get_profile_name(self):
        self._check_driver()
        profile_name = [cell.web_element.text for cell in find_all(S(".profile-name"))]
        return profile_name if profile_name else ""
    
    def _get_location(self):
        self._check_driver()
        location = [cell.web_element.text for cell in find_all(S("fields-card > ul > li > label-with-icon > span"))]
        return location

    def _get_general_information(self):
        self._check_driver()
        obj = {}
        element = S("fields-card > ul > li > label-with-icon")
        items = find_all(element)
        general_list = [(cell.web_element.find_element_by_tag_name('path').get_attribute("d"), cell.web_element.text)
                        for cell in items]
        for key, value in general_list:
            obj[icon_mapping[key]] = value
        return obj

    def _get_about(self):
        self._check_driver()
        if Button("READ MORE").exists():
            click(Button("READ MORE"))
        about = [cell.web_element.text for cell in find_all(S("description-card > div > span"))]
        short_about = about
        long_about = ", ".join(about[1:])
        return short_about, long_about

    def _get_highlights(self):
        self._check_driver()
        obj = {}
        highlight_element = S("profile-section > section-card > mat-card > div > div > anchored-values > div > a > div")
        highlight_list = [cell.web_element.text.split("\n") for cell in find_all(highlight_element)]
        res = list(map(lambda x: (", ".join(x[:-1]).strip(), x[-1]), highlight_list))
        for key, value in res:
            obj[key] = value
        return obj

    def _get_details(self):
        self._check_driver()
        obj = {}
        detail_element = S("row-card > profile-section > section-card > mat-card > div > div > fields-card > ul > li")
        detail_list = [cell.web_element.text.split("\n") for cell in find_all(detail_element)]
        res = list(map(lambda x: (", ".join(x[:1]).strip(), x[1:]), detail_list))
        for key, value in res:
            obj[key] = value
        return obj
    
    def _get_recentNews(self):
        self._check_driver()
        obj = {}
        recentNews_element = S("row-card > profile-section > section-card > mat-card > div > div > big-values-card > div")
        recentNews_list = [cell.web_element.text.split("\n") for cell in find_all(recentNews_element)]
        res = list(map(lambda x: (", ".join(x[:1]).strip(), x[1:]), recentNews_list))
        for key, value in res:
            obj[key] = value
        return obj

# %%
all_rnklst = []
all_names = []
all_websites = []
all_acquired_by = []
all_abouts = []
all_locations = []
all_no_employees = []
all_industries = []
all_ipo_status = []
all_founded_date = []
all_hqs = []
all_founders = []
all_operating_status = []
all_hub_tags = []
all_last_funding_types = []
all_company_types = []
all_investor_type = []
all_investment_stages = []
all_no_investors = []
all_no_funding_rounds = []
all_total_funding_amt = []
all_no_funds = []
all_no_investments = []
all_no_diversity_investments = []
all_no_exits = []
all_stock_symbols = []
all_no_lead_investors = []
all_no_lead_investments = []
all_no_acquisitions = []
all_no_current_team = []
all_no_board_members = []
all_total_products_active = []
all_product_downloads = []
all_active_tech_count = []
all_monthly_visits = []
all_monthly_visit_growth = []
all_no_articles = []
all_no_events = []
temp_list = []

big_array = [all_rnklst, all_names, all_acquired_by, all_abouts, all_locations,
             all_no_employees, all_industries, all_ipo_status, all_websites, all_founded_date,
             all_hqs, all_founders, all_operating_status, all_hub_tags,
             all_last_funding_types, all_company_types, all_investor_type, all_investment_stages,
             all_no_investors, all_no_funding_rounds, all_total_funding_amt,
             all_no_funds, all_no_investments, all_no_diversity_investments, all_no_exits,
             all_stock_symbols, all_no_lead_investors, all_no_lead_investments, all_no_acquisitions,
             all_no_current_team, all_no_board_members, all_total_products_active,
             all_product_downloads, all_active_tech_count, all_monthly_visits,
             all_monthly_visit_growth, all_no_articles, all_no_events, temp_list]

# %%
# Script Starts Here
a = 1
b = 5
for i in range(a, b):
    cbs = CrunchBaseScrapper()
    cbs.go_company_ranking(i)
    all_rnklst.append(i)
    cbs.scrape_information()
    for j in big_array:
        if len(j) < (i - a + 1):
            j.append("NA")
        if len(j) > (i - a + 1):
            print("error at company rank " + str(i))
            break
    kill_browser()

# cbs.go_company_ranking(4)
# all_rnklst.append(4)
# cbs.scrape_information()

# %%
# combine list into dataframe and print

df = pd.DataFrame({
    'CrunchBase Ranking': all_rnklst,
    'Company Name/Organisation Name': all_names,
    'Acquired by': all_acquired_by,
    'About': all_abouts,
    'Location': all_locations,
    'Number of Employees': all_no_employees,
    'Industry': all_industries,
    'IPO Status': all_ipo_status,
    'Website': all_websites,
    'Founded Date': all_founded_date,
    'Headquarters': all_hqs,
    'Founders': all_founders,
    'Operating Status': all_operating_status,
    'Hub Tags': all_hub_tags,
    'Last Funding Type': all_last_funding_types,
    'Company Type': all_company_types,
    'Investor Type': all_investor_type,
    'Investment Stage': temp_list,
    'Number of Investors': all_no_investors,
    'Number Funding Rounds': all_no_funding_rounds,
    'Total Funding Amount': all_total_funding_amt,
    'Number of exits': all_no_exits,
    'Number of Lead Investors': all_no_lead_investors,
    'Number of Acquisitions': all_no_acquisitions,
    'Number of Current Team Members (core team)': all_no_current_team,
    'Number of Board Members/Advisors': all_no_board_members,
    'Total Products Active': all_total_products_active,
    'Product Downloads in the Last 30 Days': all_product_downloads,
    'Active Tech Count': all_active_tech_count,
    'Monthly Visits': all_monthly_visits,
    'Monthly Visits Growth': all_monthly_visit_growth,
    'Number of Articles': all_no_articles,
    'Number of Events': all_no_events,
    'Number of Funds': all_no_funds,
    'Number of Investments': all_no_investments,
    'Number of Diversity Investments': all_no_diversity_investments,
    'Number of Exits': all_no_exits,
    'Related Hubs': all_hub_tags,
    'Investor Type': temp_list,
    'Stock Symbol': all_stock_symbols,
    'IPO Date': temp_list,
    'Number of Sub': temp_list,
    'Organisations': temp_list,
    'Funding Rounds': temp_list,
    'Funds Raised (for VC)': temp_list,
    'Number of Lead Investments': temp_list
})

# %%
df
# Out:
#    CrunchBase Ranking Company Name/Organisation Name Acquired by  \
# 0                   1                       softbank          NA
# 1                   2                     compassinc          NA
# 2                   3      zoom-video-communications          NA
# 3                   4                      crowdcube          NA
#
#                                                About  \
# 0  [SoftBank provides fixed-line, mobile telephon...
# 1  [Compass is a real estate technology company t...
# 2  [Zoom is a software company that offers a comm...
# 3  [Crowdcube is an equity crowdfunding platform ...
#
#                               Location Number of Employees  \
# 0                  Tokyo, Tokyo, Japan              10001+
# 1    New York, New York, United States              10001+
# 2  San Jose, California, United States           1001-5000
# 3        Exeter, Devon, United Kingdom              51-100
#
#                                             Industry IPO Status  \
# 0  [Banking, Finance, Internet, Mobile, Telecommu...         NA
# 1  [Marketplace, Property Management, Real Estate...    Private
# 2  [Collaboration, Information Technology, Messag...     Public
# 3  [Business Development, Finance, Financial Serv...         NA
#
#               Website   Founded Date  ... Number of Diversity Investments  \
# 0     global.softbank  [Sep 3, 1981]  ...                              24
# 1     www.compass.com  [Oct 4, 2012]  ...                              NA
# 2             zoom.us         [2011]  ...                              NA
# 3  www.crowdcube.com/  [Aug 1, 2010]  ...                              16
#
#   Number of Exits Related Hubs Stock Symbol IPO Date Number of Sub  \
# 0              53           NA   [TYO:9984]       NA            NA
# 1              NA           NA           NA       NA            NA
# 2              NA           NA           NA       NA            NA
# 3              29           NA           NA       NA            NA
#
#   Organisations Funding Rounds Funds Raised (for VC)  \
# 0            NA             NA                    NA
# 1            NA             NA                    NA
# 2            NA             NA                    NA
# 3            NA             NA                    NA
#
#   Number of Lead Investments
# 0                         NA
# 1                         NA
# 2                         NA
# 3                         NA
#
# [4 rows x 45 columns]

# %%
# all_rnklst = [x for x in all_rnklst if str(x) != 'NA']

big_array = [all_rnklst, all_names, all_acquired_by, all_abouts, all_locations,
             all_no_employees, all_industries, all_ipo_status, all_websites, all_founded_date,
             all_hqs, all_founders, all_operating_status, all_hub_tags,
             all_last_funding_types, all_company_types, all_investor_type, all_investment_stages,
             all_no_investors, all_no_funding_rounds, all_total_funding_amt,
             all_no_funds, all_no_investments, all_no_diversity_investments, all_no_exits,
             all_stock_symbols, all_no_lead_investors, all_no_lead_investments, all_no_acquisitions,
             all_no_current_team, all_no_board_members, all_total_products_active,
             all_product_downloads, all_active_tech_count, all_monthly_visits,
             all_monthly_visit_growth, all_no_articles, all_no_events, temp_list]

for i in big_array:
    print(i)
# Out:
# [277, 278, 279, 280, 281, 282, 283, 284, 285, 286, 287, 288, 289, 290, 291, 292, 293, 294, 295, 296, 297, 298, 299]
# ['bitmain', 'grubhub', 'hsbc', 'udemy', 'sonos', 'sonos', 'satellogic', 'j%C3%BCsto', 'mdlive', 'studypad-splash-math', 'ubisoft', 'ubisoft', 'fictiv', 'binance', 'binance', 'oatly', 'flywireco', 'flywireco', 'flywireco', 'cicc', 'triller', 'docusign', 'docusign']
# ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']
# [['Bitmain is a design and manufacture of high performance computing chips and software.', 'Bitmain is a manufacturer of Bitcoin mining hardware and other related services.\nBitmain was founded by several of the digital currency industry’s earliest players, and their team is comprised of passionate and pedigreed engineers, financial experts, and Bitcoin enthusiasts.\nBitmain is headquartered in Beijing and has offices in San Francisco,', 'Tel Aviv, Hong Kong, Chengdu and Shenzhen.'], ['Grubhub is a online and mobile food ordering and delivery marketplace dedicated to connecting diners with local restaurants.', 'technology, easy-to-use platforms and an improved delivery experience. Grubhub features nearly 300,000 restaurants and is proud to partner with more than 200,000 of these restaurants in over 4,000 U.S. cities. The Grubhub portfolio of brands includes Grubhub, Seamless, LevelUp, AllMenus and MenuPages.'], ['HSBC is a British banking and financial services organization that offers a comprehensive range of services.', "HSBC is one of the banking and financial services organisations in the world. HSBC's international network comprises around 8,000 offices in 87 countries and territories in Europe, the Asia-Pacific region, the Americas, the Middle East and Africa.\nWith listings on the London, Hong Kong, New York, Paris and Bermuda stock exchanges, shares in", 'HSBC Holdings plc are held by around 220,000 shareholders in 119 countries and territories. The shares are traded on the New York Stock Exchange in the form of American Depositary Receipts. Through an international network linked by advanced technology, including a rapidly growing e-commerce capability, HSBC provides a comprehensive range of financial services: personal financial services; commercial banking; corporate, investment banking and markets; private banking; and other activities.'], ['Udemy is an online learning platform that helps students, companies, and governments gain the skills they need to reach their goals.', 'programming and data science to leadership and team building. For companies, Udemy for Business offers an employee training and development platform with subscription access to 8,500+ courses, learning analytics, as well as the ability to host and distribute their own content. Udemy for Government is designed to upskill workers and prepare them for the jobs of tomorrow. Eighty percent of Fortune 100 companies trust Udemy for employee upskilling. Udemy is privately held and headquartered in San Francisco with offices in Denver, Brazil, India, Ireland, and Turkey. Udemy investors include Insight Partners, Prosus (Naspers Ventures), Norwest Venture Partners, Stripes, and Benesse Holdings.'], ['Sonos is a wireless multi-room music system enabling users to play music anywhere in the house and control it using a smartphone.', 'Sonos is a developer of wireless multi-room music systems for the home. The Sonos Multi-Room Music System is the first, wireless multi-room music system that plays all kinds of music and is able to control it. Sonos liberates the music stored on a computer so it can be enjoyed all over the house.\nIn addition, by partnering with audio services like', 'Audible.com, Last.FM, Napster, Pandora, RadioTime, Rhapsody, SIRIUS Internet Radio, and more, Sonos gives music lovers instant, computer-free access to millions of songs, thousands of radio stations, audiobooks, and more.'], ['Sonos is a wireless multi-room music system enabling users to play music anywhere in the house and control it using a smartphone.', 'Sonos is a developer of wireless multi-room music systems for the home. The Sonos Multi-Room Music System is the first, wireless multi-room music system that plays all kinds of music and is able to control it. Sonos liberates the music stored on a computer so it can be enjoyed all over the house.\nIn addition, by partnering with audio services like', 'Audible.com, Last.FM, Napster, Pandora, RadioTime, Rhapsody, SIRIUS Internet  ...
# ['Beijing, Beijing, China', 'Chicago, Illinois, United States', 'London, England, United Kingdom', 'San Francisco, California, United States', 'Santa Barbara, California, United States', 'Santa Barbara, California, United States', 'Palo Alto, California, United States', 'Mexico City, Distrito Federal, Mexico', 'Miramar Beach, Florida, United States', 'San Francisco, California, United States', 'Montreuil-sous-bois, Ile-de-France, France', 'Montreuil-sous-bois, Ile-de-France, France', 'San Francisco, California, United States', 'Valletta, NA - Malta, Malta', 'Valletta, NA - Malta, Malta', 'Malmö, Skane Lan, Sweden', 'Boston, Massachusetts, United States', 'Boston, Massachusetts, United States', 'Boston, Massachusetts, United States', 'Beijing, Beijing, China', 'New York, New York, United States', 'San Francisco, California, United States', 'San Francisco, California, United States']
# ['101-250', '1001-5000', '10001+', '501-1000', '251-500', '251-500', '101-250', '251-500', '251-500', '101-250', '5001-10000', '5001-10000', '101-250', '251-500', '251-500', '251-500', '251-500', '251-500', '251-500', '1001-5000', '11-50', '1001-5000', '1001-5000']
# [['Application Specific Integrated Circuit (ASIC)', 'Bitcoin', 'Electronics', 'Manufacturing', 'Semiconductor'], ['Apps', 'E-Commerce', 'Food and Beverage', 'Food Delivery', 'Internet', 'Marketplace', 'Mobile Apps', 'Restaurants'], ['Banking', 'Finance', 'Financial Services'], ['E-Learning', 'EdTech', 'Education', 'Training'], ['Audio', 'Consumer Electronics', 'Hardware', 'Music', 'Software', 'Wireless'], ['Audio', 'Consumer Electronics', 'Hardware', 'Music', 'Software', 'Wireless'], ['Network Hardware', 'Real Time', 'Satellite Communication'], ['Consumer Goods', 'Delivery', 'E-Commerce', 'Food and Beverage', 'Grocery'], ['Health Care', 'Hospital', 'Medical', 'mHealth', 'Virtual Workforce'], ['E-Learning', 'EdTech', 'Education', 'Mobile Apps'], ['Media and Entertainment', 'Publishing', 'Video Games'], ['Media and Entertainment', 'Publishing', 'Video Games'], ['3D Printing', 'Artificial Intelligence', 'Hardware', 'Manufacturing', 'Mechanical Engineering'], ['Bitcoin', 'Cryptocurrency', 'Ethereum', 'Finance', 'FinTech', 'Internet', 'Stock Exchanges'], ['Bitcoin', 'Cryptocurrency', 'Ethereum', 'Finance', 'FinTech', 'Internet', 'Stock Exchanges'], ['Food and Beverage', 'Nutrition', 'Wellness'], ['Financial Services', 'FinTech', 'Payments'], ['Financial Services', 'FinTech', 'Payments'], ['Financial Services', 'FinTech', 'Payments'], ['Banking', 'Finance', 'Financial Services', 'Venture Capital'], ['Digital Media', 'Music', 'Social Network', 'Software'], ['Cloud Management', 'Computer', 'E-Signature', 'Information Technology', 'SaaS', 'Software'], ['Cloud Management', 'Computer', 'E-Signature', 'Information Technology', 'SaaS', 'Software']]
# ['Private', 'Public', 'Public', 'Private', 'Public', 'Public', 'Private', 'Private', 'Private', 'Private', 'Public', 'Public', 'Private', 'Private', 'Private', 'Private', 'Private', 'Private', 'Private', 'NA', 'Private', 'Public', 'Public']
# ['www.bitmain.com', 'www.grubhub.com', 'www.hsbc.com', 'www.udemy.com', 'www.sonos.com', 'www.sonos.com', 'www.satellogic.com', 'justo.mx/', 'mdlive.com', 'www.splashlearn.com', 'www.ubisoft.com', 'www.ubisoft.com', 'www.fictiv.com/', 'www.binance.com', 'www.binance.com', 'www.oatly.com', 'www.flywire.com', 'www.flywire.com', 'www.flywire.com', 'www.cicc.com/index_en.xhtml', 'www.triller.co/', 'www.docusign.com', 'www.docusign.com']
# [['2013'], ['2004'], ['Jan 1, 1865'], ['2009'], ['Jun 30, 2002'], ['Jun 30, 2002'], ['2010'], ['May 2019'], ['2009'], ['2010'], ['Jan 1, 1986'], ['Jan 1, 1986'], ['2013'], ['2017'], ['2017'], ['Jan 1, 1990'], ['Jan 15, 2011'], ['Jan 15, 2011'], ['Jan 15, 2011'], ['Jul 31, 1995'], ['2015'], ['2003'], ['2003']]
# [['Asia-Pacific (APAC)'], ['Greater Chicago Area, Great Lakes, Midwestern US'], 'NA', ['San Francisco Bay Area, West Coast, Western US'], ['West Coast, Western US'], ['West Coast, Western US'], ['San Francisco Bay Area, Silicon Valley, West Coast'], ['Latin America'], ['East Coast, Southern US'], ['San Francisco Bay Area, West Coast, Western US'], ['European Union (EU)'], ['European Union (EU)'], ['San Francisco Bay Area, West Coast, Western US'], ['European Union (EU)'], ['European Union (EU)'], ['European Union (EU), Nordic Countries, Scandinavia'], ['Greater Boston Area, East Coast, New England'], ['Greater Boston Area, East Coast, New England'], ['Greater Boston Area, East Coast, New England'], ['Asia-Pacific (APAC)'], ['Greater New York Area, East Coast, Northeastern US'], ['San Francisco Bay Area, West Coast, Western US'], ['San Francisco Bay Area, West Coast, Western US']]
# [['Jihan Wu, Micree Zhan'], ['Jason Finger, Matt Maloney, Mike Evans'], ['Thomas Sutherland'], ['Eren Bali, Gagan Biyani, Oktay Caglar'], ['Craig Shelburne, John MacFarlane, Thomas Cullen, Trung Mai'], ['Craig Shelburne, John MacFarlane, Thomas Cullen, Trung Mai'], ['Andrew Fursman, Emiliano Kargieman'], ['Ricardo Martinez Finger, Ricardo Weder'], ['Dr Steve Gurland, Randy Parker'], ['Arpit Jain, Joy Deep Nath, Mayank Jain, Umang Jain'], ['Christian Guillemot, Claude Guillemot, Gerard Guillemot, Michel Guillemot, Yves Guillemot'], ['Christian Guillemot, Claude Guillemot, Gerard Guillemot, Michel Guillemot, Yves Guillemot'], ['Dave Evans, Nathan Evans'], ['Changpeng Zhao, Yi He'], ['Changpeng Zhao, Yi He'], ['Bjorn Oste'], ['Iker Marcaide'], ['Iker Marcaide'], ['Iker Marcaide'], 'NA', ['David Leiberman, Sammy Rubin'], ['Thomas Gonser'], ['Thomas Gonser']]
# [['Active'], ['Active'], ['Active'], ['Active'], ['Active'], ['Active'], ['Active'], ['Active'], ['Active'], ['Active'], ['Active'], ['Active'], ['Active'], ['Active'], ['Active'], ['Active'], ['Active'], ['Active'], ['Active'], ['Active'], ['Active'], ['Active'], ['Active']]
# ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']
# [['Series B'], ['Post-IPO Equity'], 'NA', ['Secondary Market'], ['Secondary Market'], ['Secondary Market'], ['Series C'], ['Series A'], ['Private Equity'], ['Series C'], ['Post-IPO Secondary'], ['Post-IPO Secondary'], ['Series D'], ['Initial Coin Offering'], ['Initial Coin Offering'], ['Private Equity'], ['Series F'], ['Series F'], ['Series F'], ['Post-IPO Equity'], ['Series B'], ['Secondary Market'], ['Secondary Market']]
# [['For Profit'], ['For Profit'], ['For Profit'], ['For Profit'], ['For Profit'], ['For Profit'], ['For Profit'], ['For Profit'], ['For Profit'], ['For Profit'], ['For Profit'], ['For Profit'], ['For Profit'], ['For Profit'], ['For Profit'], ['For Profit'], ['For Profit'], ['For Profit'], ['For Profit'], ['For Profit'], ['For Profit'], ['For Profit'], ['For Profit']]
# ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'Investment Bank, Venture Capital', 'NA', 'NA', 'NA']
# ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']
# ['12', '10', 'NA', '23', '7', '7', '10', '18', '11', '2', '4', '4', '14', '14', '14', '13', '32', '32', '32', '2', '7', 'NA', 'NA']
# ['NA', '8', 'NA', '11', '10', 'NA', '4', 'NA', 'NA', 'NA', '3', 'NA', '4', '8', '8', 'NA', '9', '9', '9', '2', '2', '19', '19']
# ['$764.7M', '$284.1M', 'NA', '$296.5M', '$455.2M', '$455.2M', '$110M', '$92M', '$198.6M', '$25M', '$770.7M', '$770.7M', '$92.6M', '$25M', '$25M', '$241.4M', '$323.2M', '$323.2M', '$323.2M', '$367M', '$33M', '$536.2M', '$536.2M']
# ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '2', 'NA', 'NA', 'NA']
# ['36', '1', '112', 'NA', '1', '1', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '15', '15', 'NA', 'NA', 'NA', 'NA', '96', 'NA', '5', '5']
# ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '2', 'NA', 'NA', 'NA']
# ['NA', 'NA', '18', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '1', '1', 'NA', 'NA', 'NA', 'NA', '21', 'NA', '1', '1']
# ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', ['HKG:3908'], 'NA', 'NA', 'NA']
# ['NA', '7', 'NA', '9', '3', 'NA', '2', 'NA', 'NA', 'NA', '1', 'NA', '3', '3', '3', 'NA', '8', '8', '8', '1', '2', 'NA', 'NA']
# ['NA', 'NA', '50', 'NA', '1', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '12', '12', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '1', '1']
# ['1', '13', '2', '1', '1', '1', 'NA', 'NA', '1', 'NA', '23', '23', 'NA', '7', '7', 'NA', '5', '5', '5', '3', '1', '7', '7']
# ['7', '14', '110', '30', '19', '19', '7', '7', '7', '5', '46', '46', '11', '9', '9', '3', '14', '14', '14', 'NA', '5', '108', '108']
# ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']
# ['20', '46', '46', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '80', '80', 'NA', '20', '20', 'NA', 'NA', '30', 'NA', 'NA', '13', '109', '109']
# ['NA', 'NA', '255,174', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '10,812,398', '10,812,398', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '87,183', '583,532', '538,183', '538,183']
# ['57', '126', '89', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '230', '230', 'NA', '61', '61', '82', 'NA', '54', 'NA', '16', '40', '82', '82']
# ['700,100', '30,753,852', '5,621,572', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '33,774,467', '33,774,467', 'NA', '61,316,487', '61,316,487', '405,613', 'NA', '733,749', 'NA', 'NA', '207,884', '29,398,879', '29,398,879']
# ['42.4%', '-2.39%', '8.13%', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '-23.14%', '-23.14%', 'NA', '48.81%', '48.81%', '-3.95%', 'NA', '33.37%', 'NA', 'NA', '1.99%', '-1.26%', '-1.26%']
# ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']
# ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']
# ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']

# %%
# combine list into dataframe and print

df2 = pd.DataFrame({
    'CrunchBase Ranking': all_rnklst,
    'Company Name/Organisation Name': all_names,
    'Acquired by': all_acquired_by,
    'About': all_abouts,
    'Location': all_locations,
    'Number of Employees': all_no_employees,
    'Industry': all_industries,
    'IPO Status': all_ipo_status,
    'Website': all_websites,
    'Founded Date': all_founded_date,
    'Headquarters': all_hqs,
    'Founders': all_founders,
    'Operating Status': all_operating_status,
    'Hub Tags': all_hub_tags,
    'Last Funding Type': all_last_funding_types,
    'Company Type': all_company_types,
    'Investor Type': all_investor_type,
    'Investment Stage': temp_list,
    'Number of Investors': all_no_investors,
    'Number Funding Rounds': all_no_funding_rounds,
    'Total Funding Amount': all_total_funding_amt,
    'Number of exits': all_no_exits,
    'Number of Lead Investors': all_no_lead_investors,
    'Number of Acquisitions': all_no_acquisitions,
    'Number of Current Team Members (core team)': all_no_current_team,
    'Number of Board Members/Advisors': all_no_board_members,
    'Total Products Active': all_total_products_active,
    'Product Downloads in the Last 30 Days': all_product_downloads,
    'Active Tech Count': all_active_tech_count,
    'Monthly Visits': all_monthly_visits,
    'Monthly Visits Growth': all_monthly_visit_growth,
    'Number of Articles': all_no_articles,
    'Number of Events': all_no_events,
    'Number of Funds': all_no_funds,
    'Number of Investments': all_no_investments,
    'Number of Diversity Investments': all_no_diversity_investments,
    'Number of Exits': all_no_exits,
    'Related Hubs': all_hub_tags,
    'Investor Type': temp_list,
    'Stock Symbol': all_stock_symbols,
    'IPO Date': temp_list,
    'Number of Sub': temp_list,
    'Organisations': temp_list,
    'Funding Rounds': temp_list,
    'Funds Raised (for VC)': temp_list,
    'Number of Lead Investments': temp_list
})

# %%
df2
# Out:
#     CrunchBase Ranking Company Name/Organisation Name Acquired by  \
# 0                  277                        bitmain          NA
# 1                  278                        grubhub          NA
# 2                  279                           hsbc          NA
# 3                  280                          udemy          NA
# 4                  281                          sonos          NA
# 5                  282                          sonos          NA
# 6                  283                     satellogic          NA
# 7                  284                     j%C3%BCsto          NA
# 8                  285                         mdlive          NA
# 9                  286           studypad-splash-math          NA
# 10                 287                        ubisoft          NA
# 11                 288                        ubisoft          NA
# 12                 289                         fictiv          NA
# 13                 290                        binance          NA
# 14                 291                        binance          NA
# 15                 292                          oatly          NA
# 16                 293                      flywireco          NA
# 17                 294                      flywireco          NA
# 18                 295                      flywireco          NA
# 19                 296                           cicc          NA
# 20                 297                        triller          NA
# 21                 298                       docusign          NA
# 22                 299                       docusign          NA
#
#                                                 About  \
# 0   [Bitmain is a design and manufacture of high p...
# 1   [Grubhub is a online and mobile food ordering ...
# 2   [HSBC is a British banking and financial servi...
# 3   [Udemy is an online learning platform that hel...
# 4   [Sonos is a wireless multi-room music system e...
# 5   [Sonos is a wireless multi-room music system e...
# 6   [Satellogic will democratize access to space-b...
# 7   [Jüsto is an online delivery-only supermarket ...
# 8   [MDLIVE is a telehealth provider of online and...
# 9   [SplashLearn is an EdTech startup company prov...
# 10  [Ubisoft is a producer, publisher, and distrib...
# 11  [Ubisoft is a producer, publisher, and distrib...
# 12  [Fictiv is a Digital Manufacturing Ecosystem t...
# 13  [Binance is a cryptocurrency exchange platform...
# 14  [Binance is a cryptocurrency exchange platform...
# 15  [Oatly delivers products that have maximum nut...
# 16  [Flywire provides a vertical payment platform ...
# 17  [Flywire provides a vertical payment platform ...
# 18  [Flywire provides a vertical payment platform ...
# 19  [CICC, a joint venture investment bank, provid...
# 20  [Triller is an AI-powered music video app that...
# 21  [DocuSign helps small- and medium-sized busine...
# 22  [DocuSign helps small- and medium-sized busine...
#
#                                       Location Number of Employees  \
# 0                      Beijing, Beijing, China             101-250
# 1             Chicago, Illinois, United States           1001-5000
# 2              London, England, United Kingdom              10001+
# 3     San Francisco, California, United States            501-1000
# 4     Santa Barbara, California, United States             251-500
# 5     Santa Barbara, California, United States             251-500
# 6         Palo Alto, California, United States             101-250
# 7        Mexico City, Distrito Federal, Mexico             251-500
# 8        Miramar Beach, Florida, United States             251-500
# 9     San Francisco, California, United States             101-250
# 10  Montreuil-sous-bois, Ile-de-France, France          5001-10000
# 11  Montreuil-sous-bois, Ile-de-France, France          5001-10000
# 12    San Francisco, California, United States             101-250
# 13                 Valletta, NA - Malta, Malta             251-500
# 14                 Valletta, NA - Malta, Malta             251-500
# 15                    Malmö, Skane Lan, Sweden             251-500
# 16        Boston, Massachusetts, United States             251-500
# 17        Boston, Massachusetts, United States             251-500
# 18        Boston, Massachusetts, United States             251-500
# 19                     Beijing, Beijing, China           1001-5000
# 20           New York, New York, United States               11-50
# 21    San Francisco, California, United States           1001-5000
# 22    San Francisco, California, United States           1001-5000
#
#                                              Industry IPO Status  \
# 0   [Application Specific Integrated Circuit (ASIC...    Private
# 1   [Apps, E-Commerce, Food and Beverage, Food Del...     Public
# 2              [Banking, Finance, Financial Services]     Public
# 3           [E-Learning, EdTech, Education, Training]    Private
# 4   [Audio, Consumer Electronics, Hardware, Music,...     Public
# 5   [Audio, Consumer Electronics, Hardware, Music,...     Public
# 6   [Network Hardware, Real Time, Satellite Commun...    Private
# 7   [Consumer Goods, Delivery, E-Commerce, Food an...    Private
# 8   [Health Care, Hospital, Medical, mHealth, Virt...    Private
# 9        [E-Learning, EdTech, Education, Mobile Apps]    Private
# 10  [Media and Entertainment, Publishing, Video Ga...     Public
# 11  [Media and Entertainment, Publishing, Video Ga...     Public
# 12  [3D Printing, Artificial Intelligence, Hardwar...    Private
# 13  [Bitcoin, Cryptocurrency, Ethereum, Finance, F...    Private
# 14  [Bitcoin, Cryptocurrency, Ethereum, Finance, F...    Private
# 15           [Food and Beverage, Nutrition, Wellness]    Private
# 16            [Financial Services, FinTech, Payments]    Private
# 17            [Financial Services, FinTech, Payments]    Private
# 18            [Financial Services, FinTech, Payments]    Private
# 19  [Banking, Finance, Financial Services, Venture...         NA
# 20   [Digital Media, Music, Social Network, Software]    Private
# 21  [Cloud Management, Computer, E-Signature, Info...     Public
# 22  [Cloud Management, Computer, E-Signature, Info...     Public
#
#                         Website    Founded Date  ...  \
# 0               www.bitmain.com          [2013]  ...
# 1               www.grubhub.com          [2004]  ...
# 2                  www.hsbc.com   [Jan 1, 1865]  ...
# 3                 www.udemy.com          [2009]  ...
# 4                 www.sonos.com  [Jun 30, 2002]  ...
# 5                 www.sonos.com  [Jun 30, 2002]  ...
# 6            www.satellogic.com          [2010]  ...
# 7                     justo.mx/      [May 2019]  ...
# 8                    mdlive.com          [2009]  ...
# 9           www.splashlearn.com          [2010]  ...
# 10              www.ubisoft.com   [Jan 1, 1986]  ...
# 11              www.ubisoft.com   [Jan 1, 1986]  ...
# 12              www.fictiv.com/          [2013]  ...
# 13              www.binance.com          [2017]  ...
# 14              www.binance.com          [2017]  ...
# 15                www.oatly.com   [Jan 1, 1990]  ...
# 16              www.flywire.com  [Jan 15, 2011]  ...
# 17              www.flywire.com  [Jan 15, 2011]  ...
# 18              www.flywire.com  [Jan 15, 2011]  ...
# 19  www.cicc.com/index_en.xhtml  [Jul 31, 1995]  ...
# 20              www.triller.co/          [2015]  ...
# 21             www.docusign.com          [2003]  ...
# 22             www.docusign.com          [2003]  ...
#
#    Number of Diversity Investments Number of Exits Related Hubs Stock Symbol  \
# 0                               NA              NA           NA           NA
# 1                               NA              NA           NA           NA
# 2                               NA              18           NA           NA
# 3                               NA              NA           NA           NA
# 4                               NA              NA           NA           NA
# 5                               NA              NA           NA           NA
# 6                               NA              NA           NA           NA
# 7                               NA              NA           NA           NA
# 8                               NA              NA           NA           NA
# 9                               NA              NA           NA           NA
# 10                              NA              NA           NA           NA
# 11                              NA              NA           NA           NA
# 12                              NA              NA           NA           NA
# 13                              NA               1           NA           NA
# 14                              NA               1           NA           NA
# 15                              NA              NA           NA           NA
# 16                              NA              NA           NA           NA
# 17                              NA              NA           NA           NA
# 18                              NA              NA           NA           NA
# 19                               2              21           NA   [HKG:3908]
# 20                              NA              NA           NA           NA
# 21                              NA               1           NA           NA
# 22                              NA               1           NA           NA
#
#    IPO Date Number of Sub Organisations Funding Rounds Funds Raised (for VC)  \
# 0        NA            NA            NA             NA                    NA
# 1        NA            NA            NA             NA                    NA
# 2        NA            NA            NA             NA                    NA
# 3        NA            NA            NA             NA                    NA
# 4        NA            NA            NA             NA                    NA
# 5        NA            NA            NA             NA                    NA
# 6        NA            NA            NA             NA                    NA
# 7        NA            NA            NA             NA                    NA
# 8        NA            NA            NA             NA                    NA
# 9        NA            NA            NA             NA                    NA
# 10       NA            NA            NA             NA                    NA
# 11       NA            NA            NA             NA                    NA
# 12       NA            NA            NA             NA                    NA
# 13       NA            NA            NA             NA                    NA
# 14       NA            NA            NA             NA                    NA
# 15       NA            NA            NA             NA                    NA
# 16       NA            NA            NA             NA                    NA
# 17       NA            NA            NA             NA                    NA
# 18       NA            NA            NA             NA                    NA
# 19       NA            NA            NA             NA                    NA
# 20       NA            NA            NA             NA                    NA
# 21       NA            NA            NA             NA                    NA
# 22       NA            NA            NA             NA                    NA
#
#    Number of Lead Investments
# 0                          NA
# 1                          NA
# 2                          NA
# 3                          NA
# 4                          NA
# 5                          NA
# 6                          NA
# 7                          NA
# 8                          NA
# 9                          NA
# 10                         NA
# 11                         NA
# 12                         NA
# 13                         NA
# 14                         NA
# 15                         NA
# 16                         NA
# 17                         NA
# 18                         NA
# 19                         NA
# 20                         NA
# 21                         NA
# 22                         NA
#
# [23 rows x 45 columns]

# %%
df2.to_csv("277-299.csv")
